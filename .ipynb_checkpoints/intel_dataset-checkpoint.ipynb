# %%
import pickle
import pandas as pd
import numpy as np

import sklearn
assert sklearn.__version__ >= "0.20"

import os

# to make this notebook's output stable across runs
np.random.seed(42)

import matplotlib as mpl
import matplotlib.pyplot as plt


#with open('dataset.pkl', 'rb') as f:
#    data = pickle.load(f)
    
data_2 = pd.read_pickle('dataset.pkl')

# %%
data_2
# Out:
#           ID             Time Group    GR1     GR2       GR3       GR4  \
# 0          0  20210901T052203     1   88.0  4000.0  0.788286  0.858421
# 1          1  20210901T052203     1  177.0  4000.0  0.842848  1.676998
# 2          2  20210901T052203     1  209.0  4000.0  0.986631  1.118038
# 3          3  20210901T052203     1  471.0  4000.0  0.986631  1.000529
# 4          4  20210901T052203     1  363.0  4000.0  0.994236  1.011487
# ...      ...              ...   ...    ...     ...       ...       ...
# 34548  34548  20211004T071217     1  648.0  4000.0  2.805979  3.251773
# 34549  34549  20211004T071217     1  294.0  4000.0  2.184607  2.785324
# 34550  34550  20211004T071217     1  499.0  4000.0  1.482132  1.759822
# 34551  34551  20211004T071217     1  398.0  4000.0  2.990628  3.041985
# 34552  34552  20211004T071217     1  119.0  4000.0  1.662435  2.029150
#
#             GR5       GR6       GR7  ...           M6     M7      M8  \
# ...

# %%
np.size(data_2)
# Out:
# 265228828

# %%
label=data_2['Class']

# %%
label
# Out:
# 0        CL146
# 1          CL6
# 2          CL6
# 3        CL187
# 4          CL6
#          ...
# 34548      CL6
# 34549      CL6
# 34550      CL6
# 34551      CL6
# 34552      CL6
# Name: Class, Length: 34553, dtype: category
# Categories (30, object): ['CL146', 'CL6', 'CL187', 'CL36', ..., 'CL266', 'CL94', 'CL7', 'CL92']

# %%
unique, counts = np.unique(label, return_counts=True)

result = np.column_stack((unique, counts)) 
print (result)
# Out:
# [['CL1' 275]
#  ['CL112' 66]
#  ['CL12' 281]
#  ['CL146' 4120]
#  ['CL147' 45]
#  ['CL153' 125]
#  ['CL167' 41]
#  ['CL168' 593]
#  ['CL187' 483]
#  ['CL2' 903]
#  ['CL200' 309]
#  ['CL208' 311]
#  ['CL233' 23]
#  ['CL244' 243]
#  ['CL266' 51]
#  ['CL29' 646]
#  ['CL327' 205]
#  ['CL36' 262]
#  ['CL37' 209]
#  ['CL376' 1842]
#  ['CL4' 219]
#  ['CL5' 181]
#  ['CL6' 21844]
#  ['CL7' 212]
#  ['CL8' 11]
#  ['CL8612' 492]
#  ['CL9' 217]
#  ['CL92' 1]
#  ['CL94' 157]
#  ['CL95' 186]]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# Assign unique integers from 0 to 6 to each star type
data_2['Class'] = le.fit_transform(data_2['Class'])
class_names = le.classes_
print(class_names)
# Out:
# ['CL1' 'CL112' 'CL12' 'CL146' 'CL147' 'CL153' 'CL167' 'CL168' 'CL187'
#  'CL2' 'CL200' 'CL208' 'CL233' 'CL244' 'CL266' 'CL29' 'CL327' 'CL36'
#  'CL37' 'CL376' 'CL4' 'CL5' 'CL6' 'CL7' 'CL8' 'CL8612' 'CL9' 'CL92' 'CL94'
#  'CL95']

# %%
labels = le.inverse_transform(data_2['Class'])

labels.shape
data_2.ndim
# Out:
# 2

# %%
labels
# Out:
# array(['CL146', 'CL6', 'CL6', ..., 'CL6', 'CL6', 'CL6'], dtype=object)

# %%
data_2.shape
# Out:
# (34553, 7676)

# %%
data_2.replace([np.inf, -np.inf], 0, inplace=True)

# %%
from sklearn.model_selection import train_test_split
data_train, data_test = train_test_split(data_2, train_size=0.75)

# %%
X_train, y_train = data_train.drop(columns=["ID", "Time","Group"]), data_train["Class"]
X_test, y_test = data_test.drop(columns=["ID", "Time","Group"]), data_test["Class"]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
X_train.replace([np.inf, -np.inf], 0, inplace=True)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-40-593b9f2914e9> in <module>
#       1 from sklearn.decomposition import PCA
#       2 pca = PCA(n_components=2)
# ----> 3 X2D = pca.fit_transform(X_train)
#
# ~/.local/lib/python3.6/site-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     381         C-ordered array, use 'np.ascontiguousarray'.
#     382         """
# --> 383         U, S, Vt = self._fit(X)
#     384         U = U[:, :self.n_components_]
#     385
#
# ~/.local/lib/python3.6/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     403
#     404         X = self._validate_data(X, dtype=[np.float64, np.float32],
# --> 405                                 ensure_2d=True, copy=self.copy)
#     406
#     407         # Handle n_components==None
#
# ...

# %%
from sklearn.multiclass import OneVsRestClassifier
ovr_clf = OneVsRestClassifier(SVC())
ovr_clf.fit(X_reduced, y_train)
#len(ovr_clf.estimators_)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-32-0959654cca0e> in <module>
#       1 from sklearn.multiclass import OneVsRestClassifier
#       2 ovr_clf = OneVsRestClassifier(SVC())
# ----> 3 ovr_clf.fit(X_train, y_train)
#       4 #len(ovr_clf.estimators_)
#
# ~/.local/lib/python3.6/site-packages/sklearn/multiclass.py in fit(self, X, y)
#     283                 "not %s" % self.label_binarizer_.classes_[i],
#     284                 self.label_binarizer_.classes_[i]])
# --> 285             for i, column in enumerate(columns))
#     286
#     287         return self
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(ovr_clf, X_train, y_train, cv=3, scoring="accuracy")
# Out:
# /home/ritwika/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ritwika/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ritwika/.local/lib/python3.6/site-packages/sklearn/multiclass.py", line 285, in fit
#     for i, column in enumerate(columns))
#   File "/home/ritwika/.local/lib/python3.6/site-packages/joblib/parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/home/ritwika/.local/lib/python3.6/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/ritwika/.local/lib/python3.6/site-packages/joblib/parallel.py", line 779, in _dispatch
# ...
