# %%
import numpy as np
import ROOT
from math import exp as expo
from math import cos as cosine
exp=np.vectorize(expo)
cos=np.vectorize(cosine)
import matplotlib.pylab as plt
from matplotlib.pyplot import figure
from BlindersPy3 import Blinders
from BlindersPy3 import FitType
import scipy.optimize as opt
# Out:
# Welcome to JupyROOT 6.24/06

# %%
# chi2_3a=np.empty(fit_range)

# %%
group=["BU/T",
"CU/T",
"Europa/T",
"IRMA/T",
"SJTU/T",
"UW/T",
"BU/A",
"CU/A",
"Europa/A",
"IRMA/A",
"SJTU/A",
"UW/A",
"BU/RT",
"Europa/RT",
"IRMA/RT",
"BU/RA",
"Europa/RA",
"UK/RQ"
]

# %%
chi2_3a=[4317/4139,
4186/4126,
4524/4133,
4111/4128,
0,
4030/4128,
4373/4139,
4219/4126,
4520/4133,
4107/4128,
0,
3981/4128,
4226/4139,
4071/4141,
4108/4131,
4109/4141,
4011/4141,         
1880/1778]

chi2_3b=[4026/4139,
4146/4131,
4248/4133,
0,
0,
4043/4128,
4151/4139,
4205/4131,
4314/4133,
0,
0,
4047/4128,
4093/4141,
4113/4141,
0,
4123/4141,
0,
1811/1780
]

# %%
len(group)
# Out:
# 18

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, chi2_3a, yerr=0, fmt="o",color="red",label="3a")
plt.errorbar(group, chi2_3b, yerr=0, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('chi2/NDF',fontsize=18)
plt.ylim([0.9,1.15])
#plt.xlim([100000,150000])
plt.legend(loc=1, prop={'size': 16})
plt.show()

# %%
R_3a=[-31.678,
-69.462,
-71.581,
-42.446,
0,
-50.511,
-31.368,
-69.245,
-71.345,
-42.329,
0,
-50.234,
-31.724,
-71.665,
-42.263,
-31.4,
-71.417,
-35.396,
]
dR_3a=[0.326,
0.330,
0.320,
0.328,
0,
0.320,
0.293,
0.298,
0.288,
0.296,
0,
0.290,
0.322,
0.332,
0.328,
0.290,
0.299,
0.399,
]
R_3b=[-30.465,
-68.128,
-70.418,
0,
0,
-49.239,
-30.64,
-68.277,
-70.536,
0,
0,
-49.402,
-30.58,
-70.276,
0,
-30.765,
0,
-33.859
]
dR_3b=[0.528,
0.523,
0.519,
0,
0,
0.519,
0.475,
0.472,
0.466,
0,
0,
0.472,
0.522,
0.533,
0,
0.47,
0,
0.643,
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, R_3a, yerr=dR_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, R_3b, yerr=dR_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('R [ppm]',fontsize=18)
plt.ylim([-73,-29])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()

# %%
R_3ab_diff=np.empty(len(group))
dR_3ab_diff=np.empty(len(group))
for i in range(0,len(group)):
    R_3ab_diff[i]=R_3b[i]-R_3a[i]
    dR_3ab_diff[i]=np.sqrt( (dR_3b[i]*dR_3b[i]) + (dR_3a[i]*dR_3a[i]) )

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, R_3ab_diff, yerr=dR_3ab_diff, fmt="o",color="black",label="3b-3a")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('dR [ppm]',fontsize=18)
plt.ylim([0.03,2.5])
#plt.xlim([100000,150000])
plt.legend(loc=2, prop={'size': 16})
plt.show()

# %%
phi_3a=[4.12069,
4.12691,
4.12031,
4.12318,
0,
2.163,
4.12125,
4.1274,
4.12087,
4.1214,
0,
2.16243,
4.12068,
4.12069,
4.12108,
4.12125,
4.12125,
4.02302
]
dphi_3a=[0.00005,
0.00005,
0.00005,
0.00005,
0.00000,
0,
0.00005,
0.00005,
0.00005,
0.00005,
0.00000,
0,
0.00005,
0.00005,
0.00005,
0.00005,
0.00005,
0.00006
]
phi_3b=[2.17532,
2.16944,
2.17571,
0,
0,
2.17568,
2.17483,
2.16901,
2.17521,
0,
0,
2.17535,
2.17535,
2.17531,
0,
2.17486,
0,
3.99678
]
dphi_3b=[0.00009,
0.00009,
0.00009,
0,
0,
0.00009,
0.00008,
0.00008,
0.00008,
0,
0,
0.00008,
0.00008,
0.00009,
0,
0.00008,
0,
0.0001
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, phi_3a, yerr=dphi_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, phi_3b, yerr=dphi_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('phase',fontsize=18)
plt.ylim([2.0,4.2])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()

# %%
N_3a=[56456000,
54712000,
58214600,
54720000,
0,
58290000,
26291900,
25767000,
27372600,
2.58E+07,
0,
26921040,
0,
0,
0,
0,
0,
0
]
dN_3a=[800,
7000,
2000,
1230,
0,
831,
300,
3000,
852,
503,
0,
338,
0,
0,
0,
0,
0,
0
]
N_3b=[22062600,
22129100,
22739600,
0,
0,
22071668,
10216900,
10269200,
10490500,
0,
0,
10282380,
0,
0,
0,
0,
0,
0
]
dN_3b=[500,
2600,
1055,
0,
0,
511,
200,
1100,
432,
0,
0,
208,
0,
0,
0,
0,
0,
0
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, N_3a, yerr=dN_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, N_3b, yerr=dN_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('N',fontsize=18)
plt.ylim([9000000,60000000])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()

# %%
tau_3a=[64.379,
64.4042,
64.377,
64.411,
0,
64.421,
64.374,
64.396,
64.370,
64.409,
0.000,
64.4211,
0,
0,
0,
0,
0,
0
]
dtau_3a=[0.004,
0.0005,
0.003,
0.004,
0.000,
0.005,
0.003,
0.007,
0.003,
0.003,
0.000,
0.0005,
0,
0,
0,
0,
0,
0
]
tau_3b=[64.371,
64.405,
64.376,
0,
0,
64.399,
64.368,
64.398,
64.372,
0,
0,
64.399,
0,
0,
0,
0,
0,
0
]
dtau_3b=[0.004,
0.007,
0.003,
0,
0,
0.0008,
0.003,
0.007,
0.003,
0,
0,
0.007,
0,
0,
0,
0,
0,
0
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, tau_3a, yerr=dtau_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, tau_3b, yerr=dtau_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('Tau [us]',fontsize=18)
plt.ylim([64.36,64.43])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()

# %%
tau_3ab_diff=np.empty(len(group))
dtau_3ab_diff=np.empty(len(group))
for i in range(0,len(group)):
    tau_3ab_diff[i]=tau_3b[i]-tau_3a[i]
    dtau_3ab_diff[i]=np.sqrt( (dtau_3b[i]*dtau_3b[i]) + (dtau_3a[i]*dtau_3a[i]) )

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, tau_3ab_diff, yerr=dtau_3ab_diff, fmt="o",color="black",label="3b-3a")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('dtau [us]',fontsize=18)
plt.ylim([-0.03,0.02])
#plt.xlim([100000,150000])
plt.legend(loc=2, prop={'size': 16})
plt.show()

# %%
Asym_3a=[0.37263,
0.37469,
0.37384,
0.3747,
0.00000,
0.3732,
0.35662,
0.358536,
0.36385,
0.35780,
0.00000,
0.360204,
0.37263,
0.36702,
0.37468,
0.35662,
0.35656,
0.22935
]
dAsym_3a=[0.00001,
0.00001,
0.00001,
0.00001,
0.00000,
0.00001,
0.00001,
0.000009,
0.00001,
0.00001,
0.00000,
0.000009,
0.00001,
0.00001,
0.00001,
0.00001,
0.00001,
0.00001
]
Asym_3b=[0.36853,
0.37223,
0.36976,
0,
0,
0.37466,
0.35588,
0.35952,
0.36264,
0,
0,
0.35819,
0.36853,
0.36301,
0,
0.35588,
0,
0.22845
]
dAsym_3b=[0.00002,
0.00002,
0.00002,
0,
0,
0.00002,
0.00001,
0.00001,
0.00001,
0,
0,
0.00001,
0.00002,
0.00002,
0,
0.00001,
0,
0.00001
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, Asym_3a, yerr=dAsym_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, Asym_3b, yerr=dAsym_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('Asymmetry',fontsize=18)
plt.ylim([0.225,0.38])
#plt.xlim([100000,150000])
plt.legend(loc=1, prop={'size': 16})
plt.show()

# %%
omega_cbo_3a=[2.3192,
2.3295,
2.3292,
2.3291,
0.0000,
2.3292,
2.3191,
2.3294,
2.3291,
2.3290,
0.0000,
2.3291,
2.3291,
2.3291,
2.3294,
2.329,
2.3292,
2.3289
]
domega_cbo_3a=[0.0001,
0.0002,
0.0001,
0.0001,
0.0000,
0.0001,
0.0001,
0.0001,
0.0001,
0.0001,
0.0000,
0.0001,
0.0001,
0.0004,
0.0003,
0.0001,
0.0003,
0.0001
]
omega_cbo_3b=[2.3317,
2.3318,
2.3319,
0,
0,
2.3318,
2.3317,
2.3317,
2.3318,
0,
0,
2.3317,
2.3317,
2.3325,
0,
2.3317,
0,
2.3313
]
domega_cbo_3b=[0.0004,
0.0003,
0.0003,
0,
0,
0.0003,
0.0003,
0.0003,
0.0003,
0,
0,
0.0003,
0.0004,
0.0013,
0,
0.0003,
0,
0.0004
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, omega_cbo_3a, yerr=domega_cbo_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, omega_cbo_3b, yerr=domega_cbo_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('omega_cbo',fontsize=18)
plt.ylim([2.316,2.335])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()

# %%
omega_cbo_3ab_diff=np.empty(len(group))
domega_cbo_3ab_diff=np.empty(len(group))
for i in range(0,len(group)):
    omega_cbo_3ab_diff[i]=omega_cbo_3b[i]-omega_cbo_3a[i]
    domega_cbo_3ab_diff[i]=np.sqrt( (domega_cbo_3b[i]*domega_cbo_3b[i]) + (domega_cbo_3a[i]*domega_cbo_3a[i]) )

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, omega_cbo_3ab_diff, yerr=domega_cbo_3ab_diff, fmt="o",color="black",label="3b-3a")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('domega_cbo',fontsize=18)
plt.ylim([0.001,0.014])
#plt.xlim([100000,150000])
plt.legend(loc=1, prop={'size': 16})
plt.show()

# %%
tau_cbo_3a=[237,
245,
256,
245,
0,
238,
247,
248,
266,
249,
0,
245,
239,
229,
272,
249,
245,
228
]
dtau_cbo_3a=[8,
6,
8,
7,
0,
7,
7,
6,
7,
6,
0,
6,
8,
23,
25,
7,
21,
7
]
tau_cbo_3b=[230,
231,
250,
0,
0,
239,
220,
237,
248,
0,
0,
237,
230,
213,
0,
230,
0,
189
]
dtau_cbo_3b=[20,
20,
23,
0,
0,
21,
20,
18,
20,
0,
0,
18,
20,
53,
0,
20,
0,
12
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, tau_cbo_3a, yerr=dtau_cbo_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, tau_cbo_3b, yerr=dtau_cbo_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('tau_cbo [us]',fontsize=18)
plt.ylim([155,300])
#plt.xlim([100000,150000])
plt.legend(loc=1, prop={'size': 16})
plt.show()

# %%
tau_cbo_3ab_diff=np.empty(len(group))
dtau_cbo_3ab_diff=np.empty(len(group))
for i in range(0,len(group)):
    tau_cbo_3ab_diff[i]=tau_cbo_3b[i]-tau_cbo_3a[i]
    dtau_cbo_3ab_diff[i]=np.sqrt( (dtau_cbo_3b[i]*dtau_cbo_3b[i]) + (dtau_cbo_3a[i]*dtau_cbo_3a[i]) )

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, tau_cbo_3ab_diff, yerr=dtau_cbo_3ab_diff, fmt="o",color="black",label="3b-3a")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('domega_cbo',fontsize=18)
plt.ylim([-80,50])
#plt.xlim([100000,150000])
plt.legend(loc=1, prop={'size': 16})
plt.show()

# %%
N_cbo_3a=[0.00286,
0.00355,
0.00288,
0.00354,
0.00000,
0.00295,
0.00303,
0.00341,
0.00308,
0.00339,
0.00000,
0.00317,
0.00286,
0.00299,
0.00348,
0.00303,
0.00314,
0.00187
]
dN_cbo_3a=[0.00003,
0.00004,
0.00003,
0.00003,
0.00000,
0.00003,
0.00003,
0.00003,
0.00003,
0.00003,
0.00000,
0.00003,
0.00003,
0.00012,
0.00010,
0.00003,
0.00011,
0.00002
]
N_cbo_3b=[0.00168,
0.00182,
0.00167,
0,
0,
0.00173,
0.00168,
0.00175,
0.00167,
0,
0,
0.00176,
0.00167,
0.0019,
0,
0.00164,
0,
0.00133
]
dN_cbo_3b=[0.00006,
0.00005,
0.00005,
0,
0,
0.00005,
0.00005,
0.00005,
0.00005,
0,
0,
0.00005,
0.00005,
0.0004,
0,
0.00005,
0,
0.00004
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, N_cbo_3a, yerr=dN_cbo_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, N_cbo_3b, yerr=dN_cbo_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('N_cbo',fontsize=18)
plt.ylim([0.0011,0.0038])
#plt.xlim([100000,150000])
plt.legend(loc=1, prop={'size': 16})
plt.show()

# %%
N_cbo_3ab_diff=np.empty(len(group))
dN_cbo_3ab_diff=np.empty(len(group))
for i in range(0,len(group)):
    N_cbo_3ab_diff[i]=N_cbo_3b[i]-N_cbo_3a[i]
    dN_cbo_3ab_diff[i]=np.sqrt( (dN_cbo_3b[i]*dN_cbo_3b[i]) + (dN_cbo_3a[i]*dN_cbo_3a[i]) )

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, N_cbo_3ab_diff, yerr=dN_cbo_3ab_diff, fmt="o",color="black",label="3b-3a")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('dN_cbo',fontsize=18)
plt.ylim([-0.002,-0.0004])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()

# %%
phi_cbo_3a=[6.130,
6.14,
6.137,
6.076,
0,
0.1545,
6.120,
6.15,
6.134,
6.094,
0.000,
0.193,
6.120,
6.116,
6.121,
6.120,
6.138,
0.458
]
dphi_cbo_3a=[0.010,
0.02,
0.011,
0.009,
0,
0.32,
0.010,
0.02,
0.009,
0.008,
0.000,
0.009,
0.010,
0.043,
0.028,
0.010,
0.034,
0.011
]
phi_cbo_3b=[0.22,
0.27,
0.2,
0,
0,
0.21,
0.2,
0.25,
0.17,
0,
0,
0.25,
0.23,
0.18,
0,
0.2,
0,
2.52
]
dphi_cbo_3b=[0.03,
0.03,
0.03,
0,
0,
0.03,
0.03,
0.03,
0.03,
0,
0,
0.02,
0.03,
0.12,
0,
0.03,
0,
0.03
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, phi_cbo_3a, yerr=dphi_cbo_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, phi_cbo_3b, yerr=dphi_cbo_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('phi_cbo',fontsize=18)
plt.ylim([0.03,6.28])
#plt.xlim([100000,150000])
plt.legend(loc=1, prop={'size': 16})
plt.show()

# %%
tau_y_3a=[0,
87,
0,
73,
0,
116,
0,
80,
62,
77,
0,
107,
0,
0,
0,
0,
0,
86
]
dtau_y_3a=[0,
15,
0,
19,
0,
68,
0,
12,
10,
18,
0,
20,
0,
0,
0,
0,
0,
9
]
tau_y_3b=[0,
40,
52,
0,
0,
68,
0,
40,
56,
0,
0,
83,
0,
0,
0,
0,
0,
61
]
dtau_y_3b=[0,
10,
10,
0,
0,
14,
0,
12,
10,
0,
0,
18,
0,
0,
0,
0,
0,
9
]

# %%
plt.figure(figsize=(20,8))
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.errorbar(group, tau_y_3a, yerr=dtau_y_3a, fmt="o",color="red",label="3a")
plt.errorbar(group, tau_y_3b, yerr=dtau_y_3b, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=18)
plt.ylabel('tau_y [us]',fontsize=18)
plt.ylim([25,190])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()

# %%
klm_3a=[0.00,
0.00,
-0.40,
0.00,
0,
0.00,
0.00,
0.00,
-0.73,
0,
0,
0,
0.00,
0.28,
0.00,
0.00,
-0.13,
0
]
klm_3b=[-0.30,
0.03,
-0.23,
0,
0,
0,
-0.30,
-0.03,
-0.32,
0.00,
0,
0,
-0.30,
-0.08,
0.00,
-0.30,
0.00,
0
]

# %%
plt.figure(figsize=(24,12))
plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=15) 
plt.errorbar(group, klm_3a, yerr=0, fmt="o",color="red",label="3a")
plt.errorbar(group, klm_3b, yerr=0, fmt="o",color="blue",label="3b")
plt.xlabel('Group/Method',fontsize=20)
plt.ylabel('muon loss int. to 300 us %',fontsize=20)
#plt.ylim([25,105])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()
