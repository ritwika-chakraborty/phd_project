# %%
import numpy as np
import ROOT
from math import exp as expo
from math import cos as cosine
exp=np.vectorize(expo)
cos=np.vectorize(cosine)
import matplotlib.pylab as plt
from matplotlib.pyplot import figure
from BlindersPy3 import Blinders
from BlindersPy3 import FitType
import scipy.optimize as opt

# %%
# chi2_3a=np.empty(fit_range)

# %%
R=[-44.554,-44.556, -44.555,-44.556,-44.556,-44.557]
dR=[0.492,0.492, 0.493, 0.495, 0.497, 0.502]
chi=[1749, 1755,1762,1771,1786,1826]

# %%
plt.figure(figsize=(16,10))
plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=15) 
plt.errorbar(scaling_factor, R, yerr=dR, fmt="o",color="red",label="R")
plt.xlabel('Scalin factor',fontsize=20)
plt.ylabel('R [ppm]',fontsize=20)
#plt.ylim([25,105])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=15) 
plt.errorbar(scaling_factor, R, yerr=0, fmt="o",color="red",label="R")
plt.xlabel('Scalin factor',fontsize=20)
plt.ylabel('R [ppm]',fontsize=20)
#plt.ylim([25,105])
#plt.xlim([100000,150000])
plt.legend(loc=1, prop={'size': 16})
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=15) 
plt.errorbar(scaling_factor, dR, yerr=0, fmt="o",color="red",label="σ_R")
plt.xlabel('Scalin factor',fontsize=20)
plt.ylabel('σ_R [ppm]',fontsize=20)
#plt.ylim([25,105])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=15) 
plt.errorbar(scaling_factor, chi, yerr=0, fmt="o",color="red",label="chi^2/NDF")
plt.xlabel('Scalin factor',fontsize=20)
plt.ylabel('chi^2/NDF',fontsize=20)
#plt.ylim([25,105])
#plt.xlim([100000,150000])
plt.legend(loc=4, prop={'size': 16})
plt.show()
