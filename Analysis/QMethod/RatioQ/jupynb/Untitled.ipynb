# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.24/06

# %%
f = ROOT.TFile.Open("run2_thresh300_fbfDQC.root")

# %%
d=f.Open("QFillByFillAnalyzerDB")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-5d9ac650bfc8> in <module>
# ----> 1 d=f.Open("QFillByFillAnalyzerDB")
#
# ~/root-6.24.06/root_v6.24.06.Linux-ubuntu18-x86_64-gcc7.5/root/lib/ROOT/pythonization/_tfile.py in _TFileOpen(klass, *args)
#      65     if f == bind_object(0, klass):
#      66         # args[0] can be either a string or a TFileOpenHandle
# ---> 67         raise OSError('Failed to open file {}'.format(str(args[0])))
#      68     return f
#      69
#
# OSError: Failed to open file QFillByFillAnalyzerDB
# Error in <TFile::TFile>: file /home/ritwika/blinding/QFillByFillAnalyzerDB does not exist

# %%
for key in f.GetListOfKeys():
    name = key.GetName()
   # entries = f.Get(name).GetEntries()
    print('{}'.format(name))
# Out:
# QFillByFillAnalyzerDB

# %%
name
# Out:
# 'QFillByFillAnalyzerDB'

# %%
from ROOT import TH1D, TCanvas
my_canvas = TCanvas("mycanvas","canvas title",800,600)
example = TH1D("example","example histogram",100,-3,3)
example.FillRandom("gaus",10000)
example.Draw("E")
my_canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: mycanvas
# Warning in <TROOT::Append>: Replacing existing TH1: example (Potential memory leak).

# %%
exampleFit = example.Fit("gaus")
# Out:
#  FCN=117.602 FROM MIGRAD    STATUS=CONVERGED      64 CALLS          65 TOTAL
#                      EDM=4.47958e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.41471e+02   2.95131e+00   1.29166e-02  -2.99182e-06
#    2  Mean        -1.60798e-02   9.99773e-03   5.31305e-05  -5.12033e-04
#    3  Sigma        9.81826e-01   6.97500e-03   1.03315e-05  -8.17434e-04

# %%
example.Draw()

# %%
my_canvas.Draw()
